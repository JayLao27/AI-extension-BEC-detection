# %% [markdown]
# # Two-Stage BEC Detection Pipeline
# This notebook splits the email into `header` (Subject, From, Reply-To) and `body`. It passes them to two separate machine learning models (Header Machine and Body Machine) and merges the outputs for final classification.

# %%
import pandas as pd
import os
import re

path = r"..\Dataset"
dataframes = {}

for root, dirs, files in os.walk(path):
    for file in files:
        if file.endswith('.csv'):
            df_name = os.path.splitext(file)[0]
            file_path = os.path.join(root, file)
            
            if os.path.getsize(file_path) == 0:
                continue

            try:
                current_df = pd.read_csv(file_path)
                
                # Specifically handle "emails.csv" (often the Enron dataset of legitimate emails)
                if df_name.lower() == 'emails' and not current_df.empty and 'label' not in current_df.columns:
                    if 'message' in current_df.columns:
                        current_df['label'] = 0  # Assuming all are Legitimate (0)
                    if 'file' in current_df.columns:
                        current_df = current_df.drop(columns=['file'])
                
                if not current_df.empty and 'label' in current_df.columns:
                    dataframes[df_name] = current_df
                    print(f"Loaded {df_name}")
            except Exception as e:
                pass
# Out:
# Loaded CEAS_08
# Loaded emails
# Loaded Ling
# Loaded Nigerian_Fraud
# Loaded phishing_email
# Loaded SpamAssasin

# %% [markdown]
# ### 1. Separate Header and Body during Data Standardization

# %%
cleaned_dfs = []

# Heuristic to separate header from body
def extract_header_body(text):
    if not isinstance(text, str):
        return "", ""
    # Standard raw emails use \n\n to separate headers and body
    parts = re.split(r'\n\s*\n', text, maxsplit=1)
    if len(parts) == 2:
        return parts[0], parts[1]
    
    # Fallback heuristic if no double newline is found
    # Assume first 150 chars contains Subject/From if not structurally split
    return text[:150], text[150:]

for name, d in dataframes.items():
    temp_df = d.copy()
    text_cols = [col for col in temp_df.columns if col != 'label']
    
    temp_df[text_cols] = temp_df[text_cols].fillna("").astype(str)
    temp_df['text_combined'] = temp_df[text_cols].agg(' '.join, axis=1)
    
    # Extract header and body
    temp_df[['header', 'body']] = temp_df['text_combined'].apply(lambda x: pd.Series(extract_header_body(x)))
    
    temp_df['label'] = pd.to_numeric(temp_df['label'], errors='coerce')
    temp_df = temp_df.dropna(subset=['label']).copy()
    temp_df['label'] = temp_df['label'].astype(int)
    
    cleaned_dfs.append(temp_df[['header', 'body', 'label']])

df = pd.concat(cleaned_dfs, ignore_index=True)

print("Merged Data Shape Before Cleaning:", df.shape)
display(df.head())
# Out:
# Merged Data Shape Before Cleaning: (651041, 3)
#                                               header  \
# 0  Young Esposito <Young@iworld.de> user4@gvc.cea...
# 1  Mok <ipline's1983@icable.ph> user2.2@gvc.ceas-...
# 2  Daily Top 10 <Karmandeep-opengevl@universalnet...
# 3  Michael Parker <ivqrnai@pobox.com> SpamAssassi...
# 4  Gretchen Suggs <externalsep1@loanofficertool.c...
#
#                                                 body  label
# 0  come. Even as Nazi tanks were rolling down the...      1
# 1                                                  1      1
# 2  =+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+...      1
# 3  For more info on the .so domain you can read a...      0
# 4                                                  1      1

# %% [markdown]
# ### 1.1 Data Cleaning - Remove Duplicates

# %%
print("--- Remove Duplicates & Missing Values ---")

rows_before = len(df)
duplicate_rows_before = df.duplicated().sum()

print(f"Rows before: {rows_before}")
print(f"Duplicate rows found: {duplicate_rows_before}")

# Remove duplicate rows
df = df.drop_duplicates().copy()

# Remove NA/missing values
na_rows_before = df.isna().any(axis=1).sum()
print(f"Missing (NA) rows found: {na_rows_before}")
df = df.dropna().copy()

rows_after = len(df)
removed_total = rows_before - rows_after

print(f"Rows after cleaning: {rows_after}")
print(f"Total rows removed (Duplicates + NAs): {removed_total}")
# Out:
# --- Remove Duplicates & Missing Values ---
# Rows before: 651041
# Duplicate rows found: 410
# Missing (NA) rows found: 0
# Rows after cleaning: 650631
# Total rows removed (Duplicates + NAs): 410

# %% [markdown]
# ### 1.1.1 Export Cleaned Dataset to Excel

# %%
# Install openpyxl if it isn't already installed, as pandas needs it to write Excel files
# %pip install openpyxl

import re

# Excel cannot handle certain hidden control characters often found in raw emails.
# We'll remove those illegal characters before exporting.
illegal_chars = re.compile(r'[\000-\010]|[\013-\014]|[\016-\037]')
df['header'] = df['header'].str.replace(illegal_chars, '', regex=True)
df['body'] = df['body'].str.replace(illegal_chars, '', regex=True)
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: openpyxl in c:\users\jay\appdata\roaming\python\python314\site-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in c:\users\jay\appdata\roaming\python\python314\site-packages (from openpyxl) (2.0.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Exporting cleaned dataset to ..\Dataset\Cleaned_BEC_Dataset.xlsx...
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (72258), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (73020), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (73240), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (73225), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (49976), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (92690), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (49990), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (93116), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (49983), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (36149), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (49992), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (93090), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (49982), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (36136), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (49987), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (36132), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (58351), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (50002), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (59732), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (49985), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (35534), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (35538), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (35525), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (72058), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (72043), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (71838), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (36133), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (49841), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (45494), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (32875), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (32881), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (32873), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (36146), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (49980), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (49984), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (92614), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (94914), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (48778), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (45126), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (49989), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (49986), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (36126), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (49975), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (49988), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (92691), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (49999), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (93150), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (49978), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (47435), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (71090), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (72072), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (71842), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (49991), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (49994), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (45598), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (71775), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (36139), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (93111), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (36140), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (95741), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (72413), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (73007), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (73213), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (72999), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (73228), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (72246), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (49995), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (46385), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (61651), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (44448), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (45584), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (94913), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (48777), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (34207), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (61661), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (72048), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (71843), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (71776), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (71081), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (72063), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (71834), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (48761), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (52166), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (49998), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (41855), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (93054), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (94919), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (48782), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (52196), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (49968), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (48748), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (46379), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (85750), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (49176), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (48756), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (52169), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (34628), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (72450), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (46145), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (47638), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (51247), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (36557), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (33154), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (41338), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (32794), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (57658), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (32814), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (43360), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (46239), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (43698), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (50395), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (33788), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (46548), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (52000), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (35031), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (45790), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (70487), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (59558), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (48031), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (45201), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (63452), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (52746), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (34024), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (32960), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (62719), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (38033), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (53057), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (56424), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (76957), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (83651), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (36357), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (33917), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (45930), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (45313), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (54998), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (144006), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (40876), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (39141), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (96540), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (79000), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (45696), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (36051), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (34093), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (40273), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (33401), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (123002), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (35148), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (40513), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (45978), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (70670), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (35488), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (33357), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (52040), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (47619), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (55528), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (36533), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (39126), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (87839), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (46944), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (34025), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (32994), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (33132), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (46118), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (52787), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (33990), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (41726), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (34453), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (32777), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (37170), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (32858), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (35795), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (33197), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (46442), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (43419), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (44374), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (34146), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (33345), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (34190), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (60654), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (38736), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (65281), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (68273), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (35772), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (36469), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (32905), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (33823), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (68959), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (33444), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (41699), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (42536), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (34109), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (40664), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (56831), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (80945), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (83047), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (34676), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (33305), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (43669), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (65032), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (46867), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (33496), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (51722), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (36003), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (33040), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (34234), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (48768), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (33420), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (41376), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (58048), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (56129), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (34615), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (35713), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (39326), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (75250), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (46773), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (65985), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (88632), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (57446), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (75266), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (65812), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (61027), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (77634), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (41102), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (48124), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (104452), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (74458), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (41224), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (96899), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (125933), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (49959), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (41991), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (79220), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (90802), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (34679), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (34184), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (45021), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (44021), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (55122), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (35621), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (34570), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (33603), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (34816), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (37018), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (34595), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (38532), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (37354), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (36208), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (32862), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (33695), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (51072), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (33967), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (36004), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (34090), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# ...
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (67431), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (40975), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (36913), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (69741), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (43854), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (39897), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (45511), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (37571), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (49782), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (58956), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (219213), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (52473), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (58776), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (141610), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (37070), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (33436), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (33734), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (39178), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (36725), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (39899), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (35576), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (37318), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (39599), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (48212), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (34867), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (41169), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (166023), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (41260), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (41426), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (42159), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (40186), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (41755), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (43606), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (43556), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (41107), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (101394), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (45820), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (44618), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (44930), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (47167), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (62271), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (55637), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (48602), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (107617), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (67514), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (59038), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (76681), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (62513), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (53552), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (56475), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (54727), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (44015), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (82259), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (52956), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (47807), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (72881), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (79229), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (124959), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (35126), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (40170), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (85561), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (87961), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (34983), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (37748), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (89348), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (33663), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (108071), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (299260), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (194668), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (37549), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (37436), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (71501), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (60081), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (41193), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (184198), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (59627), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (230906), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (124985), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (43778), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (52032), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (49936), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (67234), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (39423), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (43392), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# C:\Users\Jay\AppData\Local\Temp\ipykernel_19932\1893648344.py:16: UserWarning: Cell contents too long (88213), truncated to 32767 characters
#   df.to_excel(excel_output_path, index=False)
# Export complete!

# %% [markdown]
# ### 1.2 Text Preprocessing & Tokenization
# Clean and tokenize both the `header` and `body` text.

# %%
import nltk
from nltk.tokenize import word_tokenize

# Ensure standard tokenizers are available
nltk.download('punkt')
nltk.download('punkt_tab', quiet=True)

print("--- Tokenizing Header and Body ---")

def tokenize_text(text):
    if not isinstance(text, str):
        return []
    # Tokenize and convert to lowercase
    return word_tokenize(text.lower())

# Apply tokenization
df['header_tokenized'] = df['header'].apply(tokenize_text)
df['body_tokenized'] = df['body'].apply(tokenize_text)

print("Sample of tokenized features:")
display(df[['header_tokenized', 'body_tokenized']].head())
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Jay\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# --- Tokenizing Header and Body ---
# Sample of tokenized features:
#                                     header_tokenized  \
# 0  [young, esposito, <, young, @, iworld.de, >, u...
# 1  [mok, <, ipline's1983, @, icable.ph, >, user2....
# 2  [daily, top, 10, <, karmandeep-opengevl, @, un...
# 3  [michael, parker, <, ivqrnai, @, pobox.com, >,...
# 4  [gretchen, suggs, <, externalsep1, @, loanoffi...
#
#                                       body_tokenized
# 0  [come, ., even, as, nazi, tanks, were, rolling...
# 1                                                [1]
# 2  [=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=...
# 3  [for, more, info, on, the, .so, domain, you, c...
# 4                                                [1]

# %% [markdown]
# ### 2. Feature Extraction (TF-IDF & Word2Vec representation)

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer

train_df, test_df = train_test_split(df, test_size=0.2, random_state=42, stratify=df['label'])

# Note: The vectorizers below use the raw string ('header', 'body'), 
# which TF-IDF handles smoothly, but we've successfully stored tokenized forms if needed for other embeddings.

# TF-IDF for Headers (Machine 1)
header_vectorizer = TfidfVectorizer(max_features=2000, stop_words='english')
X_train_header = header_vectorizer.fit_transform(train_df['header'])
X_test_header = header_vectorizer.transform(test_df['header'])

# TF-IDF for Body (Machine 2) 
# Note: You can replace this with Word2Vec embeddings as per your diagram
body_vectorizer = TfidfVectorizer(max_features=5000, stop_words='english')
X_train_body = body_vectorizer.fit_transform(train_df['body'])
X_test_body = body_vectorizer.transform(test_df['body'])

y_train = train_df['label'].values
y_test = test_df['label'].values

# %% [markdown]
# ### 3. Machine 1: Header Classifier Comparison
# Compare multiple classification models (Random Forest, XGBoost, Naive Bayes) strictly on the email headers.

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.neighbors import KNeighborsClassifier
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score
import pandas as pd

# Reduced complexity for faster training
header_models = {
    'Random Forest': RandomForestClassifier(n_estimators=30, max_depth=10, random_state=42, n_jobs=-1),
    'XGBoost': XGBClassifier(n_estimators=30, max_depth=5, eval_metric='logloss', random_state=42, n_jobs=-1),
    'Naive Bayes': MultinomialNB(),
    'KNN': KNeighborsClassifier(n_neighbors=5, n_jobs=-1)
}

header_results = []
header_train_preds = {}
header_test_preds = {}
best_header_acc = 0
best_header_model_name = ""

print("--- Training Header Machines ---")
for name, model in header_models.items():
    print(f"Training {name} on headers...")
    model.fit(X_train_header, y_train)
    
    y_pred = model.predict(X_test_header)
    acc = accuracy_score(y_test, y_pred)
    header_results.append({'Model': name, 'Header Accuracy': acc})
    
    # Store predictions for stacking later
    header_train_preds[name] = model.predict_proba(X_train_header)[:, 1]
    header_test_preds[name] = model.predict_proba(X_test_header)[:, 1]
    
    if acc > best_header_acc:
        best_header_acc = acc
        best_header_model_name = name

header_df = pd.DataFrame(header_results).sort_values(by='Header Accuracy', ascending=False)
print("\nHeader Models Comparison:")
display(header_df)

print(f"\nBest Header Model: {best_header_model_name}")
# Set the best model's predictions to be used in the final stacking
best_header_train_preds = header_train_preds[best_header_model_name]
best_header_test_preds = header_test_preds[best_header_model_name]
# Out:
# --- Training Header Machines ---
# Training Random Forest on headers...
# Training XGBoost on headers...
# Training Naive Bayes on headers...
# Training KNN on headers...

# %% [markdown]
# ### 4. Machine 2: Body Classifier Comparison
# Compare multiple classification models (Naive Bayes, XGBoost, Random Forest) strictly on the email bodies.

# %%
# Reduced complexity for faster training
body_models = {
    'Random Forest': RandomForestClassifier(n_estimators=30, max_depth=10, random_state=42, n_jobs=-1),
    'XGBoost': XGBClassifier(n_estimators=30, max_depth=5, eval_metric='logloss', random_state=42, n_jobs=-1),
    'Naive Bayes': MultinomialNB(),
    'KNN': KNeighborsClassifier(n_neighbors=5, n_jobs=-1) # KNN might still be slow during prediction
}

body_results = []
body_train_preds = {}
body_test_preds = {}
best_body_acc = 0
best_body_model_name = ""

print("--- Training Body Machines ---")
for name, model in body_models.items():
    print(f"Training {name} on bodies...")
    model.fit(X_train_body, y_train)
    
    y_pred = model.predict(X_test_body)
    acc = accuracy_score(y_test, y_pred)
    body_results.append({'Model': name, 'Body Accuracy': acc})
    
    # Store predictions for stacking later
    body_train_preds[name] = model.predict_proba(X_train_body)[:, 1]
    body_test_preds[name] = model.predict_proba(X_test_body)[:, 1]
    
    if acc > best_body_acc:
        best_body_acc = acc
        best_body_model_name = name

body_df = pd.DataFrame(body_results).sort_values(by='Body Accuracy', ascending=False)
print("\nBody Models Comparison:")
display(body_df)

print(f"\nBest Body Model: {best_body_model_name}")
# Set the best model's predictions to be used in the final stacking
best_body_train_preds = body_train_preds[best_body_model_name]
best_body_test_preds = body_test_preds[best_body_model_name]
# Out:
# --- Training Body Machines ---
# Training Random Forest on bodies...
# Training XGBoost on bodies...
# Training Naive Bayes on bodies...
# Training KNN on bodies...
#
# Body Models Comparison:
#            Model  Body Accuracy
# 0  Random Forest       0.955057
# 1        XGBoost       0.936098
# 2    Naive Bayes       0.916557
# 3            KNN       0.841090
# Best Body Model: Random Forest

# %% [markdown]
# ### 5. Final Classification (Cascade / Stacking)
# Combine the outputs of the Header and Body machines.

# %%
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report

# Stack the probability features of the best header model and best body model
X_train_final = np.column_stack((best_header_train_preds, best_body_train_preds))
X_test_final = np.column_stack((best_header_test_preds, best_body_test_preds))

print(f"--- Training Final Classifier (Stacking {best_header_model_name} Header + {best_body_model_name} Body) ---")
final_model = LogisticRegression()
final_model.fit(X_train_final, y_train)

final_preds = final_model.predict(X_test_final)
final_acc = accuracy_score(y_test, final_preds)

print("\nFinal Combined Classification Report:")
print(classification_report(y_test, final_preds))
print(f"Final Cascaded Accuracy: {final_acc:.4f}")
# Out:
# --- Training Final Classifier (Stacking Random Forest Header + Random Forest Body) ---
#
# Final Combined Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99     15765
#            1       0.99      0.98      0.99     16832
#
#     accuracy                           0.99     32597
#    macro avg       0.99      0.99      0.99     32597
# weighted avg       0.99      0.99      0.99     32597
#
# Final Cascaded Accuracy: 0.9879

# %% [markdown]
# ### 6. Detailed Evaluation Reports
# Full classification reports (precision, recall, f1-score, support) for every header and body model individually.

# %%
from sklearn.metrics import classification_report

print("="*50)
print("HEADER MODELS - DETAILED REPORTS")
print("="*50)
for name, model in header_models.items():
    print(f"\n--- Header Model: {name} ---")
    # Get predictions for the test set
    y_pred_header = model.predict(X_test_header)
    # Print the full classification report (precision, recall, f1-score, support, accuracy, macro avg, weighted avg)
    print(classification_report(y_test, y_pred_header))

print("\n" + "="*50)
print("BODY MODELS - DETAILED REPORTS")
print("="*50)
for name, model in body_models.items():
    print(f"\n--- Body Model: {name} ---")
    # Get predictions for the test set
    y_pred_body = model.predict(X_test_body)
    # Print the full classification report
    print(classification_report(y_test, y_pred_body))
# Out:
# ==================================================
# HEADER MODELS - DETAILED REPORTS
# ==================================================
#
# --- Header Model: Random Forest ---
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97     15765
#            1       0.97      0.98      0.97     16832
#
#     accuracy                           0.97     32597
#    macro avg       0.97      0.97      0.97     32597
# weighted avg       0.97      0.97      0.97     32597
#
#
# --- Header Model: XGBoost ---
#               precision    recall  f1-score   support
#
#            0       0.96      0.92      0.94     15765
#            1       0.93      0.97      0.95     16832
#
#     accuracy                           0.94     32597
#    macro avg       0.95      0.94      0.94     32597
# weighted avg       0.95      0.94      0.94     32597
#
#
# --- Header Model: Naive Bayes ---
#               precision    recall  f1-score   support
#
#            0       0.93      0.95      0.94     15765
#            1       0.95      0.93      0.94     16832
#
#     accuracy                           0.94     32597
#    macro avg       0.94      0.94      0.94     32597
# weighted avg       0.94      0.94      0.94     32597
#
#
# --- Header Model: KNN ---
#               precision    recall  f1-score   support
#
#            0       0.98      0.67      0.79     15765
#            1       0.76      0.99      0.86     16832
#
#     accuracy                           0.83     32597
#    macro avg       0.87      0.83      0.83     32597
# weighted avg       0.87      0.83      0.83     32597
#
#
# ==================================================
# BODY MODELS - DETAILED REPORTS
# ==================================================
#
# --- Body Model: Random Forest ---
#               precision    recall  f1-score   support
#
#            0       0.98      0.93      0.95     15765
#            1       0.93      0.98      0.96     16832
#
#     accuracy                           0.96     32597
#    macro avg       0.96      0.95      0.95     32597
# weighted avg       0.96      0.96      0.95     32597
#
#
# --- Body Model: XGBoost ---
#               precision    recall  f1-score   support
#
#            0       0.98      0.89      0.93     15765
#            1       0.90      0.98      0.94     16832
#
#     accuracy                           0.94     32597
#    macro avg       0.94      0.93      0.94     32597
# weighted avg       0.94      0.94      0.94     32597
#
#
# --- Body Model: Naive Bayes ---
#               precision    recall  f1-score   support
#
#            0       0.91      0.91      0.91     15765
#            1       0.92      0.92      0.92     16832
#
#     accuracy                           0.92     32597
#    macro avg       0.92      0.92      0.92     32597
# weighted avg       0.92      0.92      0.92     32597
#
#
# --- Body Model: KNN ---
#               precision    recall  f1-score   support
#
#            0       0.97      0.69      0.81     15765
#            1       0.77      0.98      0.86     16832
#
#     accuracy                           0.84     32597
#    macro avg       0.87      0.84      0.84     32597
# weighted avg       0.87      0.84      0.84     32597
